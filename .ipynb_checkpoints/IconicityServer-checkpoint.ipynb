# %% [markdown]
# # Packages

# %% [markdown]
# The cell below contains the packages that are used in the code.

# %%
from mesa.visualization.modules import CanvasGrid, ChartModule
from mesa.visualization.UserParam import UserSettableParameter
from mesa.visualization.ModularVisualization import ModularServer
from mesa.batchrunner import BatchRunner
from IconicityModel import *
import pandas as pd

# workaround for the tornado 5.0 bug
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# # Agent representation
#
# This section contains code about the agent representation. Agents will be represented via circles. The colour and whether it is a filled circle or not depends on the properties of the agent.
#
# The radius of the circles indicate the age of the agent. A smaller circle represents an agent of age 0 and a bigger circle represents an agent of age 1. The colour indicates the age of acquisition of the agent; green stands for L1 signers and red for L2 signers.

# %%
def agent_representation(agent):
    iconicity_level = round(agent.iconicity_ratio() * 100)
    representation = {
                      # shape and colour of the agent
                      "Shape": "circle",
                      "Filled": "true",
                      "r": 0.5,
                      
                      # visible properties in visualisation
                      "Age of acquisition": agent.aoa,
                      "Age": agent.age,
                      "Avg. iconicity level": str(iconicity_level) + "%",
        
                      # drawing layer
                      "Layer": 0,
                      }
    
    if agent.age == 0:
        representation["r"] = 0.3
    elif agent.age == 1:
        representation["r"] = 0.5
        
    if agent.aoa == "L1":
        representation["Color"] = "green"
    elif agent.aoa == "L2":
        representation["Color"] = "red"

    return representation

# %% [markdown]
# # Grid representation
#
# This section contains code about the grid representation.

# %%
grid = CanvasGrid(agent_representation, 10, 10, 500, 500)

# %% [markdown]
# # Server representation
#
# This section contains code about the server representation.

# %%
# Word length
initial_word_length = 5
maximal_word_length = 10
minimal_word_length = 5

# Vocabulary size
initial_vocab_size = 20
maximal_vocab_size = 2 ** maximal_word_length
minimal_vocab_size = 1


model_pms = {"width":10,
             "height":10,
             "word_length": UserSettableParameter('slider', 'Word length', initial_word_length, minimal_word_length, maximal_word_length),
             "vocab_size": UserSettableParameter('slider', 'Vocabulary size', initial_vocab_size, minimal_vocab_size, maximal_vocab_size),
             "initial_degree_of_iconicity": UserSettableParameter('slider', "Initial iconicity %", 100, 0, 100),
             "learning_error_degree": UserSettableParameter('slider', "L2 learning error %", 20, 0, 100),
             "turnover_chance": UserSettableParameter('slider', 'Turnover chance (%)', 20, 0, 100),
             "turnover_threshold": UserSettableParameter('slider', 'Turnover threshold', 10, 5, 50),
             "l2_radius": UserSettableParameter('slider', 'L2 acquisition radius', 50, 1, 100),
             "l2_replace_chance": UserSettableParameter('slider', 'L2 replace chance', 50, 1, 100)}

# %%
chart = ChartModule([{"Label": "Total avg. iconicity",
                      "Color": "Black"},
                     {"Label": "L1 avg. iconicity",
                      "Color": "Green"},
                     {"Label": "L2 avg. iconicity",
                      "Color": "Red"}],
                   data_collector_name="datacollector")

# %%
#server = ModularServer(IconicityModel,
#                       [grid, chart],
#                       "Iconicity Model",
#                       model_pms)
#server.port = 8521
#server.launch()

# %% [markdown]
# # Batchrunner

# %% [markdown]
# We start by looking how the proportion of L1 and L2 signers in the replacing process of agents affects the model. In the following cell the different proportions are defined which are used in the model.

# %%
proportions = [20, 50, 75, 90]
nb_iterations = 10
nb_steps = 50

# %% [markdown]
# Then the batchrunner code is written with the fixed and variable parameters.

# %%
fixed_pm = {"width": 10,
            "height": 10,
            "vocab_size": 10,
            "word_length": 5,
            "turnover_chance": 20,
            "turnover_threshold": 10,
            "initial_degree_of_iconicity": 100,
            "learning_error_degree": 20,
            "l2_radius": 100}

variable_pm = {"l2_replace_chance": proportions}

batch_run = BatchRunner(IconicityModel,
                       variable_pm,
                       fixed_pm,
                       iterations = nb_iterations,
                       max_steps = nb_steps,
                       model_reporters={"Total avg. iconicity": compute_total_average_iconicity,
                                        "L1 avg. iconicity": compute_l1_average_iconicity,
                                        "L2 avg. iconicity": compute_l2_average_iconicity})

batch_run.run_all()
# Out:
# 40it [1:20:56, 121.41s/it]

# %% [markdown]
# Running the batchrunner for a certain amount of iterations and steps results in the following dataframe.

# %%
l2_replace_chance_data = batch_run.get_model_vars_dataframe()
l2_replace_chance_data[["l2_replace_chance", "Run", "L1 avg. iconicity", "L2 avg. iconicity", "Total avg. iconicity"]]
# Out:
#     l2_replace_chance  Run  L1 avg. iconicity  L2 avg. iconicity  \
# 0                  20    0               0.55               0.55
# 1                  20    1               0.56               0.60
# 2                  20    2               0.59               0.59
# 3                  20    3               0.53               0.52
# 4                  20    4               0.51               0.61
# 5                  20    5               0.53               0.60
# 6                  20    6               0.52               0.65
# 7                  20    7               0.50               0.58
# 8                  20    8               0.52               0.58
# 9                  20    9               0.50               0.57
# 10                 50   10               0.48               0.61
# 11                 50   11               0.53               0.61
# 12                 50   12               0.50               0.57
# ...

# %%
def calculate_average_per_iteration(data):
    parameter_values = proportions
    results = []
    
    for i in range(0, nb_iterations * len(proportions), nb_iterations):
        raw_results = data[i:i + nb_iterations].tolist()
        average_result = sum(raw_results) / len(raw_results)
        results.append(average_result)
    
    return results

def plot_average_iconicity(x_label, x_data, y_label, y_data):
    df = pd.DataFrame({x_label: x_data, y_label: y_data})
    plot = df.plot.bar(x=x_label, y=y_label, rot=0)

# %% [markdown]
# Calculate the average values over the various iterations.

# %%
total_average_iconicity = l2_replace_chance_data["Total avg. iconicity"]
l1_average_iconicity = l2_replace_chance_data["L1 avg. iconicity"]
l2_average_iconicity = l2_replace_chance_data["L2 avg. iconicity"]

avg_total_iconicity_levels = calculate_average_per_iteration(total_average_iconicity)
avg_l1_iconicity_levels = calculate_average_per_iteration(l1_average_iconicity)
avg_l2_iconicity_levels = calculate_average_per_iteration(l2_average_iconicity)

total_df = plot_average_iconicity("L1 replacement proportion (%)", proportions, "Total iconicity level", avg_total_iconicity_levels)
l1_df = plot_average_iconicity("L1 replacement proportion (%)", proportions, "L1 iconicity level", avg_l1_iconicity_levels)
l2_df = plot_average_iconicity("L1 replacement proportion (%)", proportions, "L2 iconicity level", avg_l2_iconicity_levels)
